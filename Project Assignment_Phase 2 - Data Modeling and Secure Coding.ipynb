# %% [markdown]
# #### Project Assignment: Phase 2 - Data Modeling

# %% [markdown]
# #### Author: Vidya Prabhu

# %% [markdown]
# ##### **Instructions:**
# ##### 1. Extracting Data from MongoDB
# ##### Python program will retrieve raw data from MongoDB and transform it into a well-structured format suitable for SQLite.
# ##### connect to either MongoDB Atlas (cloud) or a local MongoDB instance.
# ##### extract only the data fields relevant to your analysis, ensuring unnecessary information is excluded.
# ##### 2. Insert Data into SQLite
# ##### Create an SQLite database with properly structured tables to store the extracted data.
# ##### Validate that all data values have the correct data types before inserting them into SQLite.
# ##### Implement error-handling mechanisms to manage missing fields, such as records without lobbying activities or income data.
# ##### After completing the insertion process, print the total number of rows in the created table to verify the data transfer.
# ##### This phase ensures that the data is clean, structured, and ready for analysis in SQLite.

# %% [markdown]
# ##### Step 1: Connecting to mongo db

# %%
from pymongo import MongoClient

# Connecting to MongoDB 
client = MongoClient("mongodb+srv://vidyaprabhu96:Myuniverse20@cluster0.6x4bn.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0") 
db = client["ElectricVehiclesDB"]  # Creating database name
collection = db["ElectricVehiclesDataCollections"]  # Creating collection name

# %% [markdown]
# ##### Step 2: Verfying the connection

# %% [markdown]
# ##### 1. Verifying the database connection

# %%
try:
    # Fetching the list of databases
    db_list = client.list_database_names()

    # Checking if 'ElectricVehiclesDB' exists in the database list
    if "ElectricVehiclesDB" in db_list:
        print("Connection successful! Database exists.") # Success
    else:
        print("Connected, but 'ElectricVehiclesDB' database not found.") # failure
except Exception as e:
    # Handling connection errors and printing the error message
    print("Connection failed:", e)
# Out:
# Connection successful! Database exists.

# %% [markdown]
# ##### 2. Verifying the collection connection and displaying one record

# %%
try:
    # Fetching list of collections in the database
    collection_list = db.list_collection_names()

     # Checking if 'ElectricVehiclesDataCollections' exists in the collection list
    if "ElectricVehiclesDataCollections" in collection_list:
        print("Connection successful! Collection exists.")
        
        # Fetching a sample document from the collection
        sample_doc = collection.find_one()
        if sample_doc:
            print("Sample document:", sample_doc)
        else:
            print("Connected, but no documents found in the collection.") 
    
        # Counting the number of documents in the collection
        doc_count = collection.count_documents({})
        print("Total number of documents:", doc_count) # displaying the total records
    
    else:
        print("Connected, but 'ElectricVehiclesDataCollections' collection not found.")  # Failure

except Exception as e:
    # Handle connection errors and print the error message
    print("Connection failed:", e)
# Out:
# Connection successful! Collection exists.
# Sample document: {'_id': ObjectId('67b36f02e23a723cde1e90de'), 'sid': 'row-9exd_xzw7-2hfk', 'id': '00000000-0000-0000-F8E5-5FABDC1A77AA', 'position': 0, 'created_at': 1739484275, 'created_meta': None, 'updated_at': 1739484437, 'updated_meta': None, 'meta': '{ }', 'VIN (1-10)': '2T3YL4DV0E', 'County': 'King', 'City': 'Bellevue', 'State': 'WA', 'Postal Code': '98005', 'Model Year': '2014', 'Make': 'TOYOTA', 'Model': 'RAV4', 'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible', 'Electric Range': '103', 'Base MSRP': '0', 'Legislative District': '41', 'DOL Vehicle ID': '186450183', 'Vehicle Location': 'POINT (-122.1621 47.64441)', 'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '2020 Census Tract': '53033023604', 'Counties': '3009', 'Congressional Districts': '9', 'WAOFM - GIS - Legislative District Boundary': '49'}
# Total number of documents: 10000

# %% [markdown]
# ##### Step 3: Extracting only the data fields that are relevant to my planned data analysis task

# %%
try:
    # Defining the required fields
    required_fields = {
        "VIN (1-10)": 1, "County": 1, "City": 1, "State": 1, "Postal Code": 1,
        "Model Year": 1, "Make": 1, "Model": 1, "Electric Vehicle Type": 1,
        "Clean Alternative Fuel Vehicle (CAFV) Eligibility": 1, "Electric Range": 1,
        "Base MSRP": 1, "Legislative District": 1, "DOL Vehicle ID": 1,
        "Vehicle Location": 1, "Electric Utility": 1, "2020 Census Tract": 1,
        "Counties": 1, "Congressional Districts": 1, "WAOFM - GIS - Legislative District Boundary": 1
    }

    # Fetching only the required fields from MongoDB
    extracted_data = list(collection.find({}, required_fields))

    # Printing the first 5 records as a sample
    for record in extracted_data[:5]:
        print(record)

    print("Total extracted records:", len(extracted_data)) # checking the total count

except Exception as e:
    # Handling errors and printing the error message
    print("Data extraction failed:", e)
# Out:
# {'_id': ObjectId('67b36f02e23a723cde1e90de'), 'VIN (1-10)': '2T3YL4DV0E', 'County': 'King', 'City': 'Bellevue', 'State': 'WA', 'Postal Code': '98005', 'Model Year': '2014', 'Make': 'TOYOTA', 'Model': 'RAV4', 'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible', 'Electric Range': '103', 'Base MSRP': '0', 'Legislative District': '41', 'DOL Vehicle ID': '186450183', 'Vehicle Location': 'POINT (-122.1621 47.64441)', 'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '2020 Census Tract': '53033023604', 'Counties': '3009', 'Congressional Districts': '9', 'WAOFM - GIS - Legislative District Boundary': '49'}
# {'_id': ObjectId('67b36f02e23a723cde1e90df'), 'VIN (1-10)': '5YJ3E1EB6K', 'County': 'King', 'City': 'Bothell', 'State': 'WA', 'Postal Code': '98011', 'Model Year': '2019', 'Make': 'TESLA', 'Model': 'MODEL 3', 'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible', 'Electric Range': '220', 'Base MSRP': '0', 'Legislative District': '1', 'DOL Vehicle ID': '478093654', 'Vehicle Location': 'POINT (-122.20563 47.76144)', 'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '2020 Census Tract': '53033022102', 'Counties': '3009', 'Congressional Districts': '1', 'WAOFM - GIS - Legislative District Boundary': '1'}
# {'_id': ObjectId('67b36f02e23a723cde1e90e0'), 'VIN (1-10)': '5UX43EU02S', 'County': 'Thurston', 'City': 'Olympia', 'State': 'WA', 'Postal Code': '98502', 'Model Year': '2025', 'Make': 'BMW', 'Model': 'X5', 'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible', 'Electric Range': '40', 'Base MSRP': '0', 'Legislative District': '35', 'DOL Vehicle ID': '274800718', 'Vehicle Location': 'POINT (-122.92333 47.03779)', 'Electric Utility': 'PUGET SOUND ENERGY INC', '2020 Census Tract': '53067011902', 'Counties': '2742', 'Congressional Districts': '10', 'WAOFM - GIS - Legislative District Boundary': '28'}
# {'_id': ObjectId('67b36f02e23a723cde1e90e1'), 'VIN (1-10)': 'JTMAB3FV5R', 'County': 'Thurston', 'City': 'Olympia', 'State': 'WA', 'Postal Code': '98513', 'Model Year': '2024', 'Make': 'TOYOTA', 'Model': 'RAV4 PRIME', 'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible', 'Electric Range': '42', 'Base MSRP': '0', 'Legislative District': '2', 'DOL Vehicle ID': '260758165', 'Vehicle Location': 'POINT (-122.81754 46.98876)', 'Electric Utility': 'PUGET SOUND ENERGY INC', '2020 Census Tract': '53067012332', 'Counties': '2742', 'Congressional Districts': '10', 'WAOFM - GIS - Legislative District Boundary': '28'}
# {'_id': ObjectId('67b36f02e23a723cde1e90e2'), 'VIN (1-10)': '5YJYGDEE8M', 'County': 'Yakima', 'City': 'Selah', 'State': 'WA', 'Postal Code': '98942', 'Model Year': '2021', 'Make': 'TESLA', 'Model': 'MODEL Y', 'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched', 'Electric Range': '0', 'Base MSRP': '0', 'Legislative District': '15', 'DOL Vehicle ID': '236581355', 'Vehicle Location': 'POINT (-120.53145 46.65405)', 'Electric Utility': 'PACIFICORP', '2020 Census Tract': '53077003200', 'Counties': '2746', 'Congressional Districts': '4', 'WAOFM - GIS - Legislative District Boundary': '22'}
# Total extracted records: 10000

# %%
# Checking for duplicates of vin in the data- because I am using it as primary key while inserting into SQLlite database
vin_set = set()
duplicates = 0
for record in extracted_data:
    vin = record.get("VIN (1-10)", None)
    if vin in vin_set:
        duplicates += 1
    else:
        vin_set.add(vin)

print(f"Total duplicates found: {duplicates}")
# Out:
# Total duplicates found: 5845

# %% [markdown]
# ##### There are around 5845 duplicate records that have duplicate values for VIN. As it is an identification number it must be distinct. Therefore I will keep the records unique as I will be using it as a primary key in SQLlite

# %%
#code to keep only unique values
unique_data = []
vin_set = set()

for record in extracted_data:
    vin = record.get("VIN (1-10)", None)
    if vin not in vin_set:
        vin_set.add(vin)
        unique_data.append(record)  # Keeping only unique records

print(f"Total unique records: {len(unique_data)}")
# Out:
# Total unique records: 4155

# %% [markdown]
# ##### Step 4: Connecting to the SQL lite database

# %%
import sqlite3 #importing sqllite

conn = sqlite3.connect('ElectricVehiclesData.sqlite') # connecting to created database in SQLlite
cur = conn.cursor() # Initilaizing cursor

# Creating table if not exists
cur.execute("""
        CREATE TABLE IF NOT EXISTS ElectricVehicles (
            VIN TEXT PRIMARY KEY,
            County TEXT,
            City TEXT,
            State TEXT,
            PostalCode TEXT,
            ModelYear INTEGER,
            Make TEXT,
            Model TEXT,
            VehicleType TEXT,
            CAFV_Eligibility TEXT,
            ElectricRange INTEGER,
            BaseMSRP INTEGER,
            LegislativeDistrict TEXT,
            DOLVehicleID INTEGER,
            VehicleLocation TEXT,
            ElectricUtility TEXT,
            CensusTract TEXT,
            Counties TEXT,
            CongressionalDistricts TEXT,
            LegislativeBoundary TEXT
        )
    """)
conn.commit() # committing the action

# %% [markdown]
# ##### Step 5: Verifying if the table is created successfully

# %%
# Verifying if the table is created successfully
cur.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='ElectricVehicles';")
table_check = cur.fetchone()

if table_check:
    print("Table 'ElectricVehicles' created") #Success
else:
    print("Table 'ElectricVehicles' creation failed.")# failure
# Out:
# Table 'ElectricVehicles' created

# %% [markdown]
# ##### Step 6: Validating data and Inserting data into SQLlite

# %%
# Inserting data into SQLite
for record in unique_data:
    try:
        # Extracting and validating each field
        # If any column or key is missing in document then it will return None so that is why get("column name", None) is used for all columns
        vin = record.get("VIN (1-10)", None)
        county = record.get("County", None)
        city = record.get("City", None)
        state = record.get("State", None)
        postal_code = record.get("Postal Code", None)
        model_year = int(record.get("Model Year", 0))  # Converting to integer
        make = record.get("Make", None)
        model = record.get("Model", None)
        vehicle_type = record.get("Electric Vehicle Type", None)
        cafv_eligibility = record.get("Clean Alternative Fuel Vehicle (CAFV) Eligibility", None)
        electric_range = int(record.get("Electric Range", 0))  # Converting to integer
        base_msrp = int(record.get("Base MSRP", 0))  # Converting to integer
        legislative_district = record.get("Legislative District", None)
        dol_vehicle_id = record.get("DOL Vehicle ID", 0)
        vehicle_location = record.get("Vehicle Location", None)
        electric_utility = record.get("Electric Utility", None)
        census_tract = record.get("2020 Census Tract", None)
        counties = record.get("Counties", None)
        congressional_districts = record.get("Congressional Districts", None)
        legislative_boundary = record.get("WAOFM - GIS - Legislative District Boundary", None)

        # Inserting data into SQLite
        # ? is used because the rubric says to consider the parameterized queries while inserting
        cur.execute("""
            INSERT OR REPLACE INTO ElectricVehicles(
                VIN, County, City, State, PostalCode, ModelYear, Make, Model, VehicleType,
                CAFV_Eligibility, ElectricRange, BaseMSRP, LegislativeDistrict, DOLVehicleID,
                VehicleLocation, ElectricUtility, CensusTract, Counties, CongressionalDistricts, LegislativeBoundary
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            vin, county, city, state, postal_code, model_year, make, model, vehicle_type,
            cafv_eligibility, electric_range, base_msrp, legislative_district, dol_vehicle_id,
            vehicle_location, electric_utility, census_tract, counties, congressional_districts, legislative_boundary
        ))

    except Exception as insert_error:
        print("Skipping record due to error:", insert_error)

# Committing all insertions
conn.commit()

# Printing total rows inserted
cur.execute("SELECT COUNT(*) FROM ElectricVehicles")
total_rows = cur.fetchone()[0]
print("Total records inserted into SQLite:", total_rows)  # Success
# Out:
# Total records inserted into SQLite: 4155

# %% [markdown]
# ##### **NOTE**:
# ##### The above mentioned total records count in sqllite is accurate because even though I extracted **10,000** records from mongodb at the begining I removed the duplicate values as I used it as primary key in database.
#
# ##### **VIN stands for vehicle identification number**

# %% [markdown]
# ##### Step 7:  Validating for any null values or empty values in database

# %%
# Checking for NULL values in each column
columns = [
    "VIN", "County", "City", "State", "PostalCode", "ModelYear", "Make", "Model", "VehicleType",
    "CAFV_Eligibility", "ElectricRange", "BaseMSRP", "LegislativeDistrict", "DOLVehicleID",
    "VehicleLocation", "ElectricUtility", "CensusTract", "Counties", "CongressionalDistricts", "LegislativeBoundary"
]

# Checking for NULL values in each column
for column in columns:
    query = f"SELECT COUNT(*) FROM ElectricVehicles WHERE {column} IS NULL OR {column} = ''"
    cur.execute(query)
    null_count = cur.fetchone()[0]
    print(f"{column} has {null_count} NULL/empty values.")
# Out:
# VIN has 0 NULL/empty values.
# County has 0 NULL/empty values.
# City has 0 NULL/empty values.
# State has 0 NULL/empty values.
# PostalCode has 0 NULL/empty values.
# ModelYear has 0 NULL/empty values.
# Make has 0 NULL/empty values.
# Model has 0 NULL/empty values.
# VehicleType has 0 NULL/empty values.
# CAFV_Eligibility has 0 NULL/empty values.
# ElectricRange has 0 NULL/empty values.
# BaseMSRP has 0 NULL/empty values.
# LegislativeDistrict has 0 NULL/empty values.
# DOLVehicleID has 0 NULL/empty values.
# VehicleLocation has 0 NULL/empty values.
# ElectricUtility has 0 NULL/empty values.
# CensusTract has 0 NULL/empty values.
# Counties has 3 NULL/empty values.
# CongressionalDistricts has 0 NULL/empty values.
# LegislativeBoundary has 0 NULL/empty values.

# %% [markdown]
# ##### It's great that none of the columns contain null or empty values!

# %% [markdown]
# ##### Step 8: Printing out the rows from the sqllite table

# %%
from tabulate import tabulate 
cur.execute("SELECT * FROM ElectricVehicles")
all_records = cur.fetchall()

# Fetch column names
column_names = [desc[0] for desc in cur.description]

# Printing records 
print("All records in SQLite:")
print(column_names)  # Printing column headers
for record in all_records:
    print(record)
# Out:
# All records in SQLite:
# ['VIN', 'County', 'City', 'State', 'PostalCode', 'ModelYear', 'Make', 'Model', 'VehicleType', 'CAFV_Eligibility', 'ElectricRange', 'BaseMSRP', 'LegislativeDistrict', 'DOLVehicleID', 'VehicleLocation', 'ElectricUtility', 'CensusTract', 'Counties', 'CongressionalDistricts', 'LegislativeBoundary']
# ('2T3YL4DV0E', 'King', 'Bellevue', 'WA', '98005', 2014, 'TOYOTA', 'RAV4', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 103, 0, '41', 186450183, 'POINT (-122.1621 47.64441)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023604', '3009', '9', '49')
# ('5YJ3E1EB6K', 'King', 'Bothell', 'WA', '98011', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '1', 478093654, 'POINT (-122.20563 47.76144)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022102', '3009', '1', '1')
# ('5UX43EU02S', 'Thurston', 'Olympia', 'WA', '98502', 2025, 'BMW', 'X5', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 40, 0, '35', 274800718, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067011902', '2742', '10', '28')
# ('JTMAB3FV5R', 'Thurston', 'Olympia', 'WA', '98513', 2024, 'TOYOTA', 'RAV4 PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 42, 0, '2', 260758165, 'POINT (-122.81754 46.98876)', 'PUGET SOUND ENERGY INC', '53067012332', '2742', '10', '28')
# ('5YJYGDEE8M', 'Yakima', 'Selah', 'WA', '98942', 2021, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '15', 236581355, 'POINT (-120.53145 46.65405)', 'PACIFICORP', '53077003200', '2746', '4', '22')
# ('3C3CFFGE1G', 'Thurston', 'Olympia', 'WA', '98501', 2016, 'FIAT', '500', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '22', 294762219, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067010802', '2742', '10', '28')
# ('5YJ3E1EA4J', 'Snohomish', 'Marysville', 'WA', '98271', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '39', 270125096, 'POINT (-122.1677 48.11026)', 'PUGET SOUND ENERGY INC', '53061052808', '3213', '2', '40')
# ('5YJ3E1EA3K', 'King', 'Seattle', 'WA', '98102', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '43', 238776492, 'POINT (-122.32427 47.63433)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033006600', '3009', '7', '4')
# ('1N4AZ0CP5E', 'Thurston', 'Yelm', 'WA', '98597', 2014, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '2', 257246118, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012421', '2742', '10', '2')
# ('5YJSA1S25F', 'Thurston', 'Yelm', 'WA', '98597', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '2', 161974606, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012532', '2742', '10', '2')
# ('5YJSA1E27G', 'Snohomish', 'Everett', 'WA', '98208', 2016, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '21', 136945966, 'POINT (-122.18637 47.89251)', 'PUGET SOUND ENERGY INC', '53061041701', '3213', '1', '45')
# ('1G1FX6S03H', 'Kitsap', 'Port Orchard', 'WA', '98366', 2017, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '26', 176855283, 'POINT (-122.63847 47.54103)', 'PUGET SOUND ENERGY INC', '53035092200', '848', '6', '33')
# ('1N4AZ0CP0F', 'King', 'North Bend', 'WA', '98045', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '5', 173630845, 'POINT (-121.7831 47.49348)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032705', '3009', '8', '6')
# ('5YJSA1E25F', 'Snohomish', 'Mukilteo', 'WA', '98275', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '21', 272673852, 'POINT (-122.29196 47.89908)', 'PUGET SOUND ENERGY INC', '53061042001', '3213', '2', '7')
# ('1N4AZ1CP4J', 'Snohomish', 'Bothell', 'WA', '98012', 2018, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 151, 0, '1', 325466319, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061052009', '3213', '1', '1')
# ('7SAYGAEEXP', 'Snohomish', 'Bothell', 'WA', '98012', 2023, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 239956958, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061051933', '3213', '1', '1')
# ('WBY1Z6C33H', 'Kitsap', 'Kingston', 'WA', '98346', 2017, 'BMW', 'I3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 81, 0, '23', 215241162, 'POINT (-122.4977 47.79802)', 'PUGET SOUND ENERGY INC', '53035940000', '848', '6', '29')
# ('1N4AZ0CP3D', 'King', 'Bellevue', 'WA', '98008', 2013, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 75, 0, '48', 146512131, 'POINT (-122.11867 47.63131)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023000', '3009', '9', '49')
# ('WBY1Z4C58E', 'Kitsap', 'Poulsbo', 'WA', '98370', 2014, 'BMW', 'I3', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 72, 0, '23', 143669452, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035091100', '848', '6', '29')
# ('5YJ3E1EB0J', 'Thurston', 'Olympia', 'WA', '98512', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '35', 104823078, 'POINT (-122.9131 47.01359)', 'PUGET SOUND ENERGY INC', '53067012730', '2742', '10', '28')
# ('1G1FX6S03J', 'Snohomish', 'Lake Stevens', 'WA', '98258', 2018, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '44', 333426614, 'POINT (-122.06402 48.01497)', 'PUGET SOUND ENERGY INC', '53061052607', '3213', '1', '45')
# ('5YJSA1E25H', 'Kitsap', 'Port Orchard', 'WA', '98367', 2017, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '35', 113869640, 'POINT (-122.68516 47.50645)', 'PUGET SOUND ENERGY INC', '53035092901', '848', '6', '33')
# ('5YJXCDE26J', 'Snohomish', 'Bothell', 'WA', '98021', 2018, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '1', 109898680, 'POINT (-122.18384 47.8031)', 'PUGET SOUND ENERGY INC', '53061051938', '3213', '1', '1')
# ('1N4AZ0CP1F', 'Thurston', 'Olympia', 'WA', '98502', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '22', 226741833, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067010600', '2742', '10', '28')
# ('5YJ3E1EA5J', 'Snohomish', 'Snohomish', 'WA', '98290', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '39', 235141224, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052105', '3213', '1', '45')
# ('5UXTA6C09P', 'King', 'Renton', 'WA', '98057', 2023, 'BMW', 'X5', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 30, 0, '11', 235979348, 'POINT (-122.20489 47.47532)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033025704', '3009', '9', '17')
# ('5YJ3E1EA1L', 'Thurston', 'Olympia', 'WA', '98513', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 266, 0, '2', 104932131, 'POINT (-122.81754 46.98876)', 'PUGET SOUND ENERGY INC', '53067012331', '2742', '10', '28')
# ('5YJ3E1EA6J', 'Snohomish', 'Bothell', 'WA', '98012', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '21', 475403085, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061051922', '3213', '1', '1')
# ('KNDCD3LDXK', 'Thurston', 'Olympia', 'WA', '98501', 2019, 'KIA', 'NIRO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 26, 0, '22', 166396163, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067010400', '2742', '10', '28')
# ('1N4BZ1CP3K', 'Kitsap', 'Bremerton', 'WA', '98310', 2019, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 150, 0, '23', 274258582, 'POINT (-122.61136 47.5752)', 'PUGET SOUND ENERGY INC', '53035080400', '848', '6', '29')
# ('3FMTK3SU1P', 'Yakima', 'Yakima', 'WA', '98908', 2023, 'FORD', 'MUSTANG MACH-E', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '14', 260501132, 'POINT (-120.60272 46.59656)', 'PACIFICORP', '53077000904', '2746', '4', '20')
# ('1N4BZ0CP7H', 'Kitsap', 'Kingston', 'WA', '98346', 2017, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 107, 0, '23', 204965267, 'POINT (-122.4977 47.79802)', 'PUGET SOUND ENERGY INC', '53035090102', '848', '6', '29')
# ('1N4AZ1CP7J', 'King', 'Sammamish', 'WA', '98075', 2018, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 151, 0, '41', 196764998, 'POINT (-122.03539 47.61344)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032213', '3009', '8', '47')
# ('5YJ3E1EA6K', 'King', 'Seatac', 'WA', '98198', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '33', 218112261, 'POINT (-122.32192 47.40139)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033028802', '3009', '9', '36')
# ('KNDCC3LGXK', 'King', 'Burien', 'WA', '98146', 2019, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 239, 0, '34', 3523768, 'POINT (-122.36178 47.49408)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033026700', '3009', '7', '37')
# ('5YJ3E1EA3J', 'King', 'Redmond', 'WA', '98052', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '48', 326314649, 'POINT (-122.13158 47.67858)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022606', '3009', '1', '49')
# ('KNDCC3LG6M', 'Thurston', 'Olympia', 'WA', '98506', 2021, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '22', 272282552, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067010200', '2742', '10', '28')
# ('1N4AZ1CP1K', 'King', 'Bellevue', 'WA', '98007', 2019, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 150, 0, '41', 477871159, 'POINT (-122.12056 47.61334)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023401', '3009', '9', '49')
# ('KM8JBDD28R', 'Kitsap', 'Bremerton', 'WA', '98337', 2024, 'HYUNDAI', 'TUCSON', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 33, 0, '35', 274038677, 'POINT (-122.62749 47.565)', 'PUGET SOUND ENERGY INC', '53035080600', '848', '6', '33')
# ('WA1VABGE3K', 'King', 'Seattle', 'WA', '98144', 2019, 'AUDI', 'E-TRON', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 204, 0, '37', 244772055, 'POINT (-122.30866 47.57874)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033009500', '3009', '9', '38')
# ('1C4RJXP67S', 'Snohomish', 'Edmonds', 'WA', '98026', 2025, 'JEEP', 'WRANGLER', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 21, 0, '21', 276829122, 'POINT (-122.31768 47.87166)', 'PUGET SOUND ENERGY INC', '53061050200', '3213', '2', '7')
# ('JN1AZ0CP7C', 'Snohomish', 'Everett', 'WA', '98204', 2012, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 73, 0, '21', 239055477, 'POINT (-122.27557 47.88936)', 'PUGET SOUND ENERGY INC', '53061041901', '3213', '2', '7')
# ('1G1FZ6S07L', 'Skagit', 'Anacortes', 'WA', '98221', 2020, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 259, 0, '40', 123581125, 'POINT (-122.61214 48.51748)', 'PUGET SOUND ENERGY INC', '53057940201', '3212', '2', '43')
# ('1N4AZ0CP2D', 'Thurston', 'Olympia', 'WA', '98506', 2013, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 75, 0, '22', 114529264, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012211', '2742', '10', '28')
# ('5YJ3E1EB4L', 'King', 'Seattle', 'WA', '98106', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 322, 0, '34', 263145599, 'POINT (-122.35163 47.54287)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033009900', '3009', '7', '37')
# ('1FMCU0E13R', 'Kitsap', 'Bremerton', 'WA', '98311', 2024, 'FORD', 'ESCAPE', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 37, 0, '23', 269820771, 'POINT (-122.60915 47.62631)', 'PUGET SOUND ENERGY INC', '53035091900', '848', '6', '29')
# ('WBY1Z6C32H', 'Kitsap', 'Poulsbo', 'WA', '98370', 2017, 'BMW', 'I3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 81, 0, '23', 220928641, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035091100', '848', '6', '29')
# ('5YJ3E1EA7M', 'Snohomish', 'Bothell', 'WA', '98021', 2021, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 197460658, 'POINT (-122.18384 47.8031)', 'PUGET SOUND ENERGY INC', '53061051937', '3213', '1', '1')
# ('5YJYGDEE0L', 'King', 'Seattle', 'WA', '98108', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '37', 127485886, 'POINT (-122.30346 47.55379)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033010001', '3009', '9', '17')
# ('1N4AZ0CP4E', 'Thurston', 'Olympia', 'WA', '98502', 2014, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '35', 7083947, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067011901', '2742', '10', '28')
# ('KNDC3DLC6R', 'Yakima', 'Wapato', 'WA', '98951', 2024, 'KIA', 'EV6', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '15', 275052214, 'POINT (-120.42083 46.44779)', 'PACIFICORP', '53077940007', '2746', '4', '22')
# ('1G1RA6E43D', 'Thurston', 'Olympia', 'WA', '98502', 2013, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 38, 0, '22', 8448723, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067010510', '2742', '10', '28')
# ('1N4AZ0CP9F', 'Yakima', 'Yakima', 'WA', '98903', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '14', 264913883, 'POINT (-120.4778 46.55351)', 'PACIFICORP', '53077002803', '2746', '4', '22')
# ('WMWXP3C05M', 'Snohomish', 'Everett', 'WA', '98201', 2021, 'MINI', 'HARDTOP', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 110, 0, '38', 123225651, 'POINT (-122.20596 47.97659)', 'PUGET SOUND ENERGY INC', '53061040100', '3213', '2', '40')
# ('1N4AZ1CP3K', 'King', 'Duvall', 'WA', '98019', 2019, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 150, 0, '45', 334762830, 'POINT (-121.98609 47.74068)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032401', '3009', '1', '47')
# ('WBAJB1C58K', 'Thurston', 'Lacey', 'WA', '98503', 2019, 'BMW', '530E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 15, 55700, '22', 475113859, 'POINT (-122.82324 47.04437)', 'PUGET SOUND ENERGY INC', '53067011410', '2742', '10', '28')
# ('1FMCU0E15R', 'Thurston', 'Olympia', 'WA', '98502', 2024, 'FORD', 'ESCAPE', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 37, 0, '22', 269184583, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067011100', '2742', '10', '28')
# ('5YJ3E1EA7J', 'Snohomish', 'Snohomish', 'WA', '98290', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '44', 476233649, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052502', '3213', '1', '45')
# ('WA1E2AFY5M', 'Thurston', 'Olympia', 'WA', '98502', 2021, 'AUDI', 'Q5 E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 18, 0, '22', 269927080, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067012002', '2742', '10', '28')
# ('1G1RC6E43F', 'Thurston', 'Olympia', 'WA', '98501', 2015, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 38, 0, '22', 115490966, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067010300', '2742', '10', '28')
# ('5YJXCBE25G', 'Thurston', 'Olympia', 'WA', '98513', 2016, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 200, 0, '2', 245054981, 'POINT (-122.81754 46.98876)', 'PUGET SOUND ENERGY INC', '53067012320', '2742', '10', '28')
# ('5YJ3E1EA0J', 'Kitsap', 'Port Orchard', 'WA', '98367', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '35', 233773956, 'POINT (-122.68516 47.50645)', 'PUGET SOUND ENERGY INC', '53035092901', '848', '6', '33')
# ('7SAYGDEE4P', 'Snohomish', 'Bothell', 'WA', '98012', 2023, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 252829629, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061051935', '3213', '1', '1')
# ('LPSED3KA7M', 'King', 'Burien', 'WA', '98166', 2021, 'POLESTAR', 'PS2', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 233, 0, '34', 176320490, 'POINT (-122.34102 47.46593)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033027800', '3009', '7', '37')
# ('5YJ3E1EB1L', 'Snohomish', 'Snohomish', 'WA', '98290', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 322, 0, '39', 263254666, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052301', '3213', '1', '45')
# ('5YJ3E1EB5N', 'Yakima', 'Union Gap', 'WA', '98903', 2022, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '15', 198844712, 'POINT (-120.4778 46.55351)', 'PACIFICORP', '53077001400', '2746', '4', '22')
# ('JTDKARFP9K', 'Kitsap', 'Poulsbo', 'WA', '98370', 2019, 'TOYOTA', 'PRIUS PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 25, 0, '23', 340612723, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035090502', '848', '6', '29')
# ('JTMEB3FV4R', 'Walla Walla', 'Walla Walla', 'WA', '99362', 2024, 'TOYOTA', 'RAV4 PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 42, 0, '16', 259935749, 'POINT (-118.34261 46.07068)', 'PACIFICORP', '53071920702', '2743', '5', '23')
# ('1G1FZ6S0XL', 'Ferry', 'Kettle Falls', 'WA', '99141', 2020, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 259, 0, '7', 103500155, 'POINT (-118.06211 48.61053)', 'AVISTA CORP', '53019970100', '2741', '5', '10')
# ('1FTZR0816Y', 'Thurston', 'Olympia', 'WA', '98506', 2000, 'FORD', 'RANGER', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 58, 0, '22', 8166497, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012100', '2742', '10', '28')
# ('5YJYGDEFXL', 'Thurston', 'Lacey', 'WA', '98503', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '22', 227488313, 'POINT (-122.82324 47.04437)', 'PUGET SOUND ENERGY INC', '53067011421', '2742', '10', '28')
# ('1G1RA6E46D', 'Thurston', 'Olympia', 'WA', '98513', 2013, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 38, 0, '2', 180215675, 'POINT (-122.81754 46.98876)', 'PUGET SOUND ENERGY INC', '53067012420', '2742', '10', '28')
# ('WA1M2BFZ4P', 'Snohomish', 'Bothell', 'WA', '98012', 2023, 'AUDI', 'Q4', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 238074623, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061051936', '3213', '1', '1')
# ('5YJ3E1EA0K', 'Snohomish', 'Everett', 'WA', '98204', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '21', 478003844, 'POINT (-122.27557 47.88936)', 'PUGET SOUND ENERGY INC', '53061041812', '3213', '2', '7')
# ('3C3CFFGEXH', 'Kitsap', 'Suquamish', 'WA', '98392', 2017, 'FIAT', '500', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '23', 111733625, 'POINT (-122.55242 47.73162)', 'PUGET SOUND ENERGY INC', '53035940100', '848', '6', '29')
# ('5YJ3E1EB3K', 'Kitsap', 'Bainbridge Island', 'WA', '98110', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '23', 477951141, 'POINT (-122.521 47.62728)', 'PUGET SOUND ENERGY INC', '53035091002', '848', '6', '29')
# ('5YJ3E1EB4J', 'Snohomish', 'Edmonds', 'WA', '98020', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '21', 475819270, 'POINT (-122.37689 47.81116)', 'PUGET SOUND ENERGY INC', '53061050403', '3213', '7', '7')
# ('5YJ3E1EB6L', 'King', 'Seattle', 'WA', '98101', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 322, 0, '43', 273489933, 'POINT (-122.34223 47.61085)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033007302', '3009', '7', '31')
# ('5YJYGDEE1M', 'Yakima', 'Yakima', 'WA', '98908', 2021, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '14', 178930706, 'POINT (-120.60272 46.59656)', 'PACIFICORP', '53077000402', '2746', '4', '20')
# ('KNDCC3LG9L', 'King', 'Seattle', 'WA', '98103', 2020, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 239, 0, '36', 262814793, 'POINT (-122.35436 47.67596)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033002800', '3009', '7', '4')
# ('1N4AZ1CP3J', 'Snohomish', 'Bothell', 'WA', '98021', 2018, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 151, 0, '1', 280293891, 'POINT (-122.18384 47.8031)', 'PUGET SOUND ENERGY INC', '53061051926', '3213', '1', '1')
# ('5YJXCAE2XJ', 'Snohomish', 'Lynnwood', 'WA', '98036', 2018, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '1', 237837610, 'POINT (-122.29245 47.82557)', 'PUGET SOUND ENERGY INC', '53061051916', '3213', '2', '21')
# ('5YJSA1E44G', 'Thurston', 'Lacey', 'WA', '98503', 2016, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '22', 289256215, 'POINT (-122.82324 47.04437)', 'PUGET SOUND ENERGY INC', '53067011422', '2742', '10', '28')
# ('WMW13DJ07P', 'Thurston', 'Olympia', 'WA', '98512', 2023, 'MINI', 'HARDTOP', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '35', 213356664, 'POINT (-122.9131 47.01359)', 'PUGET SOUND ENERGY INC', '53067011901', '2742', '10', '28')
# ('1G1RB6E4XF', 'Snohomish', 'Monroe', 'WA', '98272', 2015, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 38, 0, '39', 160637802, 'POINT (-121.98087 47.8526)', 'PUGET SOUND ENERGY INC', '53061052208', '3213', '1', '41')
# ('1G1FZ6S00L', 'Kitsap', 'Bremerton', 'WA', '98310', 2020, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 259, 0, '23', 109715182, 'POINT (-122.61136 47.5752)', 'PUGET SOUND ENERGY INC', '53035080400', '848', '6', '29')
# ('5YJYGDEE5L', 'Thurston', 'Olympia', 'WA', '98502', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '22', 111797045, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067010600', '2742', '10', '28')
# ('7FCTGAAA7P', 'Kitsap', 'Kingston', 'WA', '98346', 2023, 'RIVIAN', 'R1T', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '23', 272789380, 'POINT (-122.4977 47.79802)', 'PUGET SOUND ENERGY INC', '53035090102', '848', '6', '29')
# ('5YJ3E1EA2J', 'Island', 'Freeland', 'WA', '98249', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '10', 476596963, 'POINT (-122.52664 48.00956)', 'PUGET SOUND ENERGY INC', '53029971301', '3007', '2', '16')
# ('WBY1Z4C56F', 'Skagit', 'Bow', 'WA', '98232', 2015, 'BMW', 'I3', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 72, 0, '40', 180481773, 'POINT (-122.397 48.56045)', 'PUGET SOUND ENERGY INC', '53057950802', '3212', '2', '43')
# ('WBAJB1C50J', 'Skagit', 'Mount Vernon', 'WA', '98273', 2018, 'BMW', '530E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 14, 54950, '39', 139603817, 'POINT (-122.33891 48.41644)', 'PUGET SOUND ENERGY INC', '53057952304', '3212', '1', '43')
# ('KNDCM3LD6L', 'Island', 'Coupeville', 'WA', '98239', 2020, 'KIA', 'NIRO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 26, 0, '10', 154056871, 'POINT (-122.68558 48.21857)', 'PUGET SOUND ENERGY INC', '53029971000', '3007', '2', '16')
# ('KNDC3DLC1N', 'Yakima', 'Yakima', 'WA', '98902', 2022, 'KIA', 'EV6', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '14', 215088814, 'POINT (-120.52401 46.59739)', 'PACIFICORP', '53077001202', '2746', '4', '20')
# ('1N4AZ0CP4F', 'King', 'Bothell', 'WA', '98011', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '1', 4038856, 'POINT (-122.20563 47.76144)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033021804', '3009', '1', '1')
# ('2C4RC1L7XJ', 'Thurston', 'Yelm', 'WA', '98597', 2018, 'CHRYSLER', 'PACIFICA', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 33, 0, '20', 313162384, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012510', '2742', '10', '2')
# ('5YJYGDEF1L', 'Snohomish', 'Snohomish', 'WA', '98296', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '1', 134941936, 'POINT (-122.1389 47.87115)', 'PUGET SOUND ENERGY INC', '53061052112', '3213', '1', '45')
# ('3C3CFFGE4H', 'Spokane', 'Spokane', 'WA', '99203', 2017, 'FIAT', '500', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '6', 253915385, 'POINT (-117.39322 47.63374)', 'MODERN ELECTRIC WATER COMPANY', '53063004400', '3214', '5', '3')
# ('1N4AZ0CP1D', 'Skagit', 'Mount Vernon', 'WA', '98273', 2013, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 75, 0, '40', 178276696, 'POINT (-122.33891 48.41644)', 'PUGET SOUND ENERGY INC', '53057952301', '3212', '1', '43')
# ('YV4BR0DM3J', 'Kitsap', 'Poulsbo', 'WA', '98370', 2018, 'VOLVO', 'XC60', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 17, 52900, '23', 148397651, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035090202', '848', '6', '29')
# ('5YJXCAE23L', 'King', 'Seattle', 'WA', '98105', 2020, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 293, 0, '46', 2102971, 'POINT (-122.31307 47.66127)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033004101', '3009', '7', '4')
# ('1N4AZ1CP7K', 'King', 'Seattle', 'WA', '98102', 2019, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 150, 0, '43', 330872573, 'POINT (-122.32427 47.63433)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033006100', '3009', '7', '4')
# ('7SAYGDEEXP', 'Yakima', 'Yakima', 'WA', '98902', 2023, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '14', 259159092, 'POINT (-120.52401 46.59739)', 'PACIFICORP', '53077000800', '2746', '4', '20')
# ('5YJSA1E21H', 'Thurston', 'Lacey', 'WA', '98516', 2017, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '22', 185810306, 'POINT (-122.75103 47.08149)', 'PUGET SOUND ENERGY INC', '53067012226', '2742', '10', '28')
# ('JTDKARFP9H', 'Snohomish', 'Lake Stevens', 'WA', '98258', 2017, 'TOYOTA', 'PRIUS PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 25, 0, '44', 244768863, 'POINT (-122.06402 48.01497)', 'PUGET SOUND ENERGY INC', '53061052607', '3213', '1', '45')
# ('WBY2Z2C54H', 'King', 'Seattle', 'WA', '98121', 2017, 'BMW', 'I8', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 14, 0, '36', 215133656, 'POINT (-122.34468 47.61578)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033007201', '3009', '7', '31')
# ('WBY7Z2C55J', 'Kitsap', 'Poulsbo', 'WA', '98370', 2018, 'BMW', 'I3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 114, 0, '23', 210232879, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035940100', '848', '6', '29')
# ('5UXKT0C57J', 'Kitsap', 'Poulsbo', 'WA', '98370', 2018, 'BMW', 'X5', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 13, 0, '23', 252602409, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035090502', '848', '6', '29')
# ('1FADP5CUXD', 'Thurston', 'Lacey', 'WA', '98503', 2013, 'FORD', 'C-MAX', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 19, 0, '22', 124548028, 'POINT (-122.82324 47.04437)', 'PUGET SOUND ENERGY INC', '53067011421', '2742', '10', '28')
# ('5YJ3E1EB9J', 'Grant', 'Moses Lake', 'WA', '98837', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '13', 233620446, 'POINT (-119.2771 47.13196)', 'PUD NO 2 OF GRANT COUNTY', '53025011002', '2982', '4', '19')
# ('5YJ3E1EAXJ', 'Snohomish', 'Everett', 'WA', '98203', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '38', 279931011, 'POINT (-122.23019 47.94949)', 'PUGET SOUND ENERGY INC', '53061040900', '3213', '2', '40')
# ('WA1F2AFY6M', 'Island', 'Freeland', 'WA', '98249', 2021, 'AUDI', 'Q5 E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 18, 0, '10', 148575108, 'POINT (-122.52664 48.00956)', 'PUGET SOUND ENERGY INC', '53029971900', '3007', '2', '16')
# ('1N4AZ1CP7L', 'King', 'Seattle', 'WA', '98119', 2020, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 149, 0, '36', 138320423, 'POINT (-122.3684 47.64586)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033005902', '3009', '7', '31')
# ('1G1FZ6S08L', 'Kitsap', 'Poulsbo', 'WA', '98370', 2020, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 259, 0, '23', 4877211, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035090201', '848', '6', '29')
# ('KNDCS3LF8R', 'Kitsap', 'Kingston', 'WA', '98346', 2024, 'KIA', 'NIRO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 33, 0, '23', 275146042, 'POINT (-122.4977 47.79802)', 'PUGET SOUND ENERGY INC', '53035090101', '848', '6', '29')
# ('1N4AZ0CP7F', 'Thurston', 'Olympia', 'WA', '98506', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '22', 152802296, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012223', '2742', '10', '28')
# ('YV4H60DL0R', 'Snohomish', 'Bothell', 'WA', '98021', 2024, 'VOLVO', 'XC60', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 35, 0, '1', 268718775, 'POINT (-122.18384 47.8031)', 'PUGET SOUND ENERGY INC', '53061051918', '3213', '1', '1')
# ('5YJ3E1EB3J', 'King', 'Redmond', 'WA', '98052', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '48', 136665812, 'POINT (-122.13158 47.67858)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022902', '3009', '1', '49')
# ('3C3CFFGE6E', 'Kitsap', 'Bremerton', 'WA', '98312', 2014, 'FIAT', '500', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 87, 0, '35', 348695021, 'POINT (-122.6563 47.56739)', 'PUGET SOUND ENERGY INC', '53035080700', '848', '6', '33')
# ('1G1FX6S01H', 'Kitsap', 'Poulsbo', 'WA', '98370', 2017, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '23', 214494213, 'POINT (-122.64681 47.73689)', 'PUGET SOUND ENERGY INC', '53035090502', '848', '6', '29')
# ('LPSED3KA4M', 'Snohomish', 'Snohomish', 'WA', '98290', 2021, 'POLESTAR', 'PS2', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 233, 0, '44', 179405019, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052402', '3213', '1', '45')
# ('5YJSA1H23F', 'Snohomish', 'Monroe', 'WA', '98272', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '39', 171501319, 'POINT (-121.98087 47.8526)', 'PUGET SOUND ENERGY INC', '53061052207', '3213', '1', '41')
# ('1N4AZ1CP8K', 'Snohomish', 'Marysville', 'WA', '98270', 2019, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 150, 0, '44', 474812908, 'POINT (-122.1769 48.06114)', 'PUGET SOUND ENERGY INC', '53061052104', '3213', '2', '40')
# ('YV4H60CE8R', 'Snohomish', 'Bothell', 'WA', '98021', 2024, 'VOLVO', 'XC90', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 32, 0, '1', 274081699, 'POINT (-122.18384 47.8031)', 'PUGET SOUND ENERGY INC', '53061051916', '3213', '1', '1')
# ('1G1FY6S09M', 'Whitman', 'Pullman', 'WA', '99163', 2021, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '9', 265705282, 'POINT (-117.18147 46.73015)', 'AVISTA CORP', '53075000201', '2745', '5', '13')
# ('1G1RC6S5XG', 'Kitsap', 'Bremerton', 'WA', '98312', 2016, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 53, 0, '26', 251044041, 'POINT (-122.6563 47.56739)', 'PUGET SOUND ENERGY INC', '53035081100', '848', '6', '33')
# ('5YJ3E1EB7J', 'King', 'Seattle', 'WA', '98119', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '36', 474908619, 'POINT (-122.3684 47.64586)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033005902', '3009', '7', '31')
# ('5YJ3E1EA4L', 'Thurston', 'Olympia', 'WA', '98502', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 266, 0, '22', 125806859, 'POINT (-122.92333 47.03779)', 'PUGET SOUND ENERGY INC', '53067012001', '2742', '10', '28')
# ('5YJ3E1EA7L', 'Snohomish', 'Bothell', 'WA', '98012', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 266, 0, '1', 106351423, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061051934', '3213', '1', '1')
# ('3C3CFFGE6H', 'Thurston', 'Olympia', 'WA', '98506', 2017, 'FIAT', '500', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '22', 195353231, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012211', '2742', '10', '28')
# ('5YJ3E1EAXL', 'King', 'Seattle', 'WA', '98119', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 266, 0, '36', 104461920, 'POINT (-122.3684 47.64586)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033007001', '3009', '7', '31')
# ('7SAYGAEE4P', 'Thurston', 'Olympia', 'WA', '98501', 2023, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '22', 228477805, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067011721', '2742', '10', '28')
# ('JN1AZ0CPXC', 'Thurston', 'Olympia', 'WA', '98506', 2012, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 73, 0, '22', 268830397, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012223', '2742', '10', '28')
# ('1N4AZ0CP5F', 'King', 'Seattle', 'WA', '98118', 2015, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 84, 0, '37', 197700233, 'POINT (-122.2668 47.55115)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033010101', '3009', '9', '38')
# ('7SAYGDED8S', 'Snohomish', 'Bothell', 'WA', '98012', 2025, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 276989954, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061052107', '3213', '1', '1')
# ('5YJXCDE28J', 'Thurston', 'Olympia', 'WA', '98506', 2018, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '22', 274980051, 'POINT (-122.87741 47.05997)', 'PUGET SOUND ENERGY INC', '53067012100', '2742', '10', '28')
# ('KNDC4DLC0P', 'Snohomish', 'Lynnwood', 'WA', '98036', 2023, 'KIA', 'EV6', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '1', 227468839, 'POINT (-122.29245 47.82557)', 'PUGET SOUND ENERGY INC', '53061051931', '3213', '2', '21')
# ('JM3KKEHA4R', 'Kitsap', 'Port Orchard', 'WA', '98366', 2024, 'MAZDA', 'CX-90', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 26, 0, '26', 258297308, 'POINT (-122.63847 47.54103)', 'PUGET SOUND ENERGY INC', '53035092600', '848', '6', '33')
# ('5YJYGDEF3L', 'Kitsap', 'Kingston', 'WA', '98346', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '23', 104791375, 'POINT (-122.4977 47.79802)', 'PUGET SOUND ENERGY INC', '53035090101', '848', '6', '29')
# ('1G1RB6E44F', 'Yakima', 'Selah', 'WA', '98942', 2015, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 38, 0, '15', 245614274, 'POINT (-120.53145 46.65405)', 'PACIFICORP', '53077003100', '2746', '4', '22')
# ('5YJSA1E29H', 'Snohomish', 'Lynnwood', 'WA', '98087', 2017, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '21', 205776322, 'POINT (-122.27981 47.85727)', 'PUGET SOUND ENERGY INC', '53061041703', '3213', '2', '7')
# ('WBY2Z2C51F', 'Yakima', 'Yakima', 'WA', '98908', 2015, 'BMW', 'I8', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 14, 0, '14', 272252648, 'POINT (-120.60272 46.59656)', 'PACIFICORP', '53077000800', '2746', '4', '20')
# ('5YJ3E1EA5K', 'Island', 'Oak Harbor', 'WA', '98277', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '10', 477312496, 'POINT (-122.64682 48.29077)', 'PUGET SOUND ENERGY INC', '53029970602', '3007', '2', '16')
# ('JTMCB3FV0R', 'Stevens', 'Colville', 'WA', '99114', 2024, 'TOYOTA', 'RAV4 PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 42, 0, '7', 260771871, 'POINT (-117.90454 48.54657)', 'AVISTA CORP', '53065950600', '2741', '5', '10')
# ('1G1FY6S08L', 'Island', 'Langley', 'WA', '98260', 2020, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 259, 0, '10', 148652773, 'POINT (-122.40618 48.0399)', 'PUGET SOUND ENERGY INC', '53029972000', '3007', '2', '16')
# ('1N4AZ0CP6D', 'Okanogan', 'Winthrop', 'WA', '98862', 2013, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 75, 0, '12', 268494299, 'POINT (-120.17739 48.47396)', 'OKANOGAN COUNTY ELEC COOP, INC', '53047970900', '3198', '4', '18')
# ('KNDCE3LG1K', 'Island', 'Langley', 'WA', '98260', 2019, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 239, 0, '10', 127175583, 'POINT (-122.40618 48.0399)', 'PUGET SOUND ENERGY INC', '53029972000', '3007', '2', '16')
# ('KNDRMDJH2S', 'Skagit', 'Mount Vernon', 'WA', '98273', 2025, 'KIA', 'SORENTO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 30, 0, '40', 275852076, 'POINT (-122.33891 48.41644)', 'PUGET SOUND ENERGY INC', '53057951900', '3212', '1', '43')
# ('5UXTA6C09N', 'Snohomish', 'Bothell', 'WA', '98012', 2022, 'BMW', 'X5', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 30, 0, '44', 195423910, 'POINT (-122.21061 47.83448)', 'PUGET SOUND ENERGY INC', '53061052008', '3213', '1', '1')
# ('7SAYGDEE5P', 'Kitsap', 'Bremerton', 'WA', '98311', 2023, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '23', 236519867, 'POINT (-122.60915 47.62631)', 'PUGET SOUND ENERGY INC', '53035091600', '848', '6', '29')
# ('JTDKAMFP9M', 'Thurston', 'Olympia', 'WA', '98516', 2021, 'TOYOTA', 'PRIUS PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 25, 0, '22', 220545160, 'POINT (-122.75103 47.08149)', 'PUGET SOUND ENERGY INC', '53067012221', '2742', '10', '28')
# ('5YJSA1E20F', 'Snohomish', 'Snohomish', 'WA', '98290', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '44', 171724325, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052301', '3213', '1', '45')
# ('5YJ3E1EB5J', 'Kitsap', 'Silverdale', 'WA', '98383', 2018, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 215, 0, '23', 476540046, 'POINT (-122.69275 47.65171)', 'PUGET SOUND ENERGY INC', '53035091201', '848', '6', '29')
# ('1N4BZ0CP9H', 'Snohomish', 'Edmonds', 'WA', '98020', 2017, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 107, 0, '32', 179409142, 'POINT (-122.37689 47.81116)', 'PUGET SOUND ENERGY INC', '53061050700', '3213', '7', '7')
# ('5YJSA1S29F', 'Thurston', 'Olympia', 'WA', '98501', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '35', 107080018, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067011720', '2742', '10', '28')
# ('5YJSA1E2XJ', 'Thurston', 'Olympia', 'WA', '98501', 2018, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 249, 0, '35', 260491164, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067011720', '2742', '10', '28')
# ('5YJ3E1EB2L', 'Snohomish', 'Snohomish', 'WA', '98296', 2020, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 322, 0, '1', 193763258, 'POINT (-122.1389 47.87115)', 'PUGET SOUND ENERGY INC', '53061052112', '3213', '1', '45')
# ('WBY8P2C09L', 'King', 'Seattle', 'WA', '98122', 2020, 'BMW', 'I3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 153, 0, '43', 266050627, 'POINT (-122.31009 47.60803)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033008402', '3009', '9', '38')
# ('KNDCS3LF0P', 'Thurston', 'Olympia', 'WA', '98502', 2023, 'KIA', 'NIRO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 33, 0, '35', 254676936, 'POINT (-122.92333 47.03779)', 'NO KNOWN ELECTRIC UTILITY SERVICE', '53067011902', '2742', '10', '28')
# ('1C4JJXR65P', 'Skagit', 'Sedro-Woolley', 'WA', '98284', 2023, 'JEEP', 'WRANGLER', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 21, 0, '39', 277097397, 'POINT (-122.23857 48.50858)', 'PUGET SOUND ENERGY INC', '53057951600', '3212', '2', '41')
# ('1FADP5CU2D', 'Thurston', 'Lacey', 'WA', '98503', 2013, 'FORD', 'C-MAX', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 19, 0, '22', 115266077, 'POINT (-122.82324 47.04437)', 'PUGET SOUND ENERGY INC', '53067011200', '2742', '10', '28')
# ('WBA33AG00M', 'Chelan', 'Leavenworth', 'WA', '98826', 2021, 'BMW', '530E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 18, 0, '12', 271999381, 'POINT (-120.65754 47.5982)', 'PUD NO 1 OF CHELAN COUNTY', '53007960201', '2956', '8', '18')
# ('1C4RJYC66R', 'Grant', 'Moses Lake', 'WA', '98837', 2024, 'JEEP', 'GRAND CHEROKEE', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 25, 0, '13', 275309933, 'POINT (-119.2771 47.13196)', 'PUD NO 2 OF GRANT COUNTY', '53025011001', '2982', '4', '19')
# ('1G1FW6S05P', 'Stevens', 'Colville', 'WA', '99114', 2023, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '7', 263223649, 'POINT (-117.90454 48.54657)', 'AVISTA CORP', '53065950600', '2741', '5', '10')
# ('5YJYGDEF2L', 'Snohomish', 'Everett', 'WA', '98208', 2020, 'TESLA', 'MODEL Y', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 291, 0, '44', 109000167, 'POINT (-122.18637 47.89251)', 'PUGET SOUND ENERGY INC', '53061041609', '3213', '1', '45')
# ('WVWKR7AU7K', 'Snohomish', 'Snohomish', 'WA', '98290', 2019, 'VOLKSWAGEN', 'E-GOLF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 125, 0, '39', 144629278, 'POINT (-122.09305 47.91265)', 'PUGET SOUND ENERGY INC', '53061052105', '3213', '1', '45')
# ('KNDJP3AEXG', 'Snohomish', 'Everett', 'WA', '98208', 2016, 'KIA', 'SOUL', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 93, 31950, '44', 237820453, 'POINT (-122.18637 47.89251)', 'PUGET SOUND ENERGY INC', '53061041609', '3213', '1', '45')
# ('1N4BZ1DV2M', 'Chelan', 'Chelan', 'WA', '98816', 2021, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '12', 166337937, 'POINT (-120.01454 47.83985)', 'PUD NO 1 OF CHELAN COUNTY', '53007960303', '2956', '8', '18')
# ('5YJSA1E43G', 'King', 'Redmond', 'WA', '98053', 2016, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 210, 0, '45', 150383019, 'POINT (-122.03287 47.68555)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032332', '3009', '1', '47')
# ('1G1FX6S06H', 'Snohomish', 'Everett', 'WA', '98208', 2017, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '44', 321043404, 'POINT (-122.18637 47.89251)', 'PUGET SOUND ENERGY INC', '53061052119', '3213', '1', '45')
# ('WA1LAAGE3N', 'Kittitas', 'Ronald', 'WA', '98940', 2022, 'AUDI', 'E-TRON', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '13', 271034592, 'POINT (-121.02627 47.23781)', 'PUGET SOUND ENERGY INC', '53037975101', '3194', '8', '19')
# ('1N4AZ1CP1J', 'King', 'Renton', 'WA', '98056', 2018, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 151, 0, '11', 322471348, 'POINT (-122.1805 47.50006)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033025202', '3009', '9', '17')
# ('5YJ3E1EB1K', 'Thurston', 'Yelm', 'WA', '98597', 2019, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 220, 0, '2', 207652329, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012422', '2742', '10', '2')
# ...
# ('JTMAB3FV3M', 'King', 'Seattle', 'WA', '98109', 2021, 'TOYOTA', 'RAV4 PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 42, 0, '36', 151984556, 'POINT (-122.35022 47.63824)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033006702', '3009', '7', '31')
# ('JTDKN3DP9C', 'King', 'Redmond', 'WA', '98052', 2012, 'TOYOTA', 'PRIUS PLUG-IN', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 6, 0, '45', 332172592, 'POINT (-122.13158 47.67858)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032323', '3009', '1', '49')
# ('KNDCR3L10P', 'King', 'Tukwila', 'WA', '98168', 2023, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '11', 255293342, 'POINT (-122.3317 47.50314)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033027200', '3009', '7', '37')
# ('1GYKPVRL4R', 'King', 'Seattle', 'WA', '98125', 2024, 'CADILLAC', 'LYRIQ', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '46', 270552908, 'POINT (-122.30253 47.72656)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033000700', '3009', '7', '48')
# ('JN1DF0BB5P', 'King', 'Bellevue', 'WA', '98005', 2023, 'NISSAN', 'ARIYA', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '41', 272886925, 'POINT (-122.1621 47.64441)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023601', '3009', '9', '49')
# ('5UXTS1C01M', 'Snohomish', 'Edmonds', 'WA', '98020', 2021, 'BMW', 'X3', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 17, 0, '21', 140054708, 'POINT (-122.37689 47.81116)', 'PUGET SOUND ENERGY INC', '53061050501', '3213', '7', '7')
# ('KNDCS3LFXP', 'King', 'Seattle', 'WA', '98146', 2023, 'KIA', 'NIRO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 33, 0, '34', 240640907, 'POINT (-122.36178 47.49408)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033012000', '3009', '7', '37')
# ('7FCTGAAA4N', 'King', 'Renton', 'WA', '98055', 2022, 'RIVIAN', 'R1T', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '11', 213401562, 'POINT (-122.197 47.43876)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033029308', '3009', '9', '36')
# ('3FMTK4SX9M', 'Snohomish', 'Snohomish', 'WA', '98296', 2021, 'FORD', 'MUSTANG MACH-E', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '44', 194260545, 'POINT (-122.1389 47.87115)', 'PUGET SOUND ENERGY INC', '53061052105', '3213', '1', '45')
# ('4JGFB4GBXS', 'King', 'Kirkland', 'WA', '98034', 2025, 'MERCEDES-BENZ', 'GLE-CLASS', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 49, 0, '45', 276010920, 'POINT (-122.22901 47.72201)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022006', '3009', '1', '1')
# ('YV4ED3UR7M', 'Clark', 'Vancouver', 'WA', '98685', 2021, 'VOLVO', 'XC40', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '18', 177888882, 'POINT (-122.70303 45.70954)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011040908', '2977', '3', '25')
# ('1G1RD6S56H', 'Clark', 'Vancouver', 'WA', '98685', 2017, 'CHEVROLET', 'VOLT', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 53, 0, '18', 349306044, 'POINT (-122.70303 45.70954)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011040909', '2977', '3', '25')
# ('3GNKDBRJ7R', 'Clark', 'Vancouver', 'WA', '98685', 2024, 'CHEVROLET', 'BLAZER EV', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '49', 269393358, 'POINT (-122.70303 45.70954)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011040904', '2977', '3', '25')
# ('SADHD2S15N', 'King', 'Kirkland', 'WA', '98033', 2022, 'JAGUAR', 'I-PACE', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '48', 179227870, 'POINT (-122.2066 47.67887)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022702', '3009', '1', '47')
# ('1G1FX6S07J', 'King', 'Federal Way', 'WA', '98003', 2018, 'CHEVROLET', 'BOLT EV', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 238, 0, '30', 329417497, 'POINT (-122.3303 47.30151)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033030403', '3009', '9', '14')
# ('1N4BZ0CP0H', 'King', 'Bellevue', 'WA', '98006', 2017, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 107, 0, '41', 227838733, 'POINT (-122.12096 47.55584)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033024701', '3009', '9', '42')
# ('KNDAEFS53S', 'Clark', 'Brush Prairie', 'WA', '98606', 2025, 'KIA', 'EV9', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '18', 276159040, 'POINT (-122.54578 45.73473)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011040504', '2977', '3', '24')
# ('5YJXCAE49G', 'King', 'Seattle', 'WA', '98102', 2016, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 200, 0, '43', 115524762, 'POINT (-122.32427 47.63433)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033006500', '3009', '7', '4')
# ('7SAXCBE51R', 'Thurston', 'Yelm', 'WA', '98597', 2024, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '2', 266747421, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012532', '2742', '10', '2')
# ('JN1DF0CD8P', 'King', 'Bellevue', 'WA', '98007', 2023, 'NISSAN', 'ARIYA', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '41', 240527563, 'POINT (-122.12056 47.61334)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023604', '3009', '9', '49')
# ('KNDCC3LG6N', 'King', 'Seattle', 'WA', '98115', 2022, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '46', 272858085, 'POINT (-122.31676 47.68156)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033002000', '3009', '7', '4')
# ('5YJ3E1ET1R', 'King', 'Seattle', 'WA', '98125', 2024, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '46', 268217764, 'POINT (-122.30253 47.72656)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033001202', '3009', '7', '48')
# ('WA1BCBFZ9P', 'King', 'Seattle', 'WA', '98177', 2023, 'AUDI', 'Q4', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '32', 230853794, 'POINT (-122.36498 47.72238)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033000500', '3009', '7', '21')
# ('WBAJA9C56J', 'King', 'Seattle', 'WA', '98119', 2018, 'BMW', '530E', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 16, 52650, '36', 327691402, 'POINT (-122.3684 47.64586)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033005902', '3009', '7', '31')
# ('WAUUPBFF4G', 'Thurston', 'Rochester', 'WA', '98579', 2016, 'AUDI', 'A3', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 16, 0, '20', 137314810, 'POINT (-123.08743 46.82175)', 'PUGET SOUND ENERGY INC', '53067012720', '2742', '10', '27')
# ('WDDVP9AB3E', 'King', 'Kirkland', 'WA', '98034', 2014, 'MERCEDES-BENZ', 'B-CLASS', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 87, 0, '45', 218350849, 'POINT (-122.22901 47.72201)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033022003', '3009', '1', '1')
# ('KNDCE3LG0K', 'Thurston', 'Yelm', 'WA', '98597', 2019, 'KIA', 'NIRO', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 239, 0, '2', 478493809, 'POINT (-122.60735 46.94239)', 'PUGET SOUND ENERGY INC', '53067012532', '2742', '10', '2')
# ('5YJXCDE20H', 'King', 'North Bend', 'WA', '98045', 2017, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 200, 0, '5', 295464956, 'POINT (-121.7831 47.49348)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032705', '3009', '8', '6')
# ('3FMTK3SU2P', 'King', 'Bellevue', 'WA', '98005', 2023, 'FORD', 'MUSTANG MACH-E', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '48', 228093498, 'POINT (-122.1621 47.64441)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023701', '3009', '9', '49')
# ('WA124BGF2S', 'King', 'Seattle', 'WA', '98112', 2025, 'AUDI', 'Q6', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '37', 274160925, 'POINT (-122.30207 47.64085)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033007800', '3009', '7', '4')
# ('50EA1PGA2R', 'King', 'Bellevue', 'WA', '98004', 2024, 'LUCID', 'AIR', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '48', 269245399, 'POINT (-122.1872 47.61001)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023805', '3009', '9', '42')
# ('WVGTMPE28N', 'King', 'Bellevue', 'WA', '98007', 2022, 'VOLKSWAGEN', 'ID.4', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '48', 236595054, 'POINT (-122.12056 47.61334)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023201', '3009', '9', '49')
# ('JN1CF0BB3P', 'King', 'Bellevue', 'WA', '98004', 2023, 'NISSAN', 'ARIYA', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '41', 257938663, 'POINT (-122.1872 47.61001)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023807', '3009', '9', '42')
# ('YV4BR0CK2K', 'King', 'Bellevue', 'WA', '98004', 2019, 'VOLVO', 'XC90', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 17, 0, '41', 125426248, 'POINT (-122.1872 47.61001)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033023901', '3009', '9', '42')
# ('WBY43AW07P', 'King', 'Seattle', 'WA', '98178', 2023, 'BMW', 'I4', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '37', 240565097, 'POINT (-122.23825 47.49461)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033011901', '3009', '9', '38')
# ('1FADP5CU5F', 'King', 'Auburn', 'WA', '98002', 2015, 'FORD', 'C-MAX', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 19, 0, '31', 250774149, 'POINT (-122.22285 47.30507)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033031102', '3009', '8', '15')
# ('YV4H60DK5R', 'King', 'Seattle', 'WA', '98112', 2024, 'VOLVO', 'XC60', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 35, 0, '43', 272309614, 'POINT (-122.30207 47.64085)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033006300', '3009', '7', '4')
# ('YV4H600N7P', 'King', 'Issaquah', 'WA', '98027', 2023, 'VOLVO', 'XC90', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 32, 0, '5', 258829294, 'POINT (-122.03439 47.5301)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032102', '3009', '8', '6')
# ('5YJSA1E27F', 'King', 'North Bend', 'WA', '98045', 2015, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 208, 0, '5', 115813239, 'POINT (-121.7831 47.49348)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032704', '3009', '8', '6')
# ('JTJKKCFZ6N', 'Kitsap', 'Seabeck', 'WA', '98380', 2022, 'LEXUS', 'NX', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 37, 0, '35', 207092560, 'POINT (-122.81585 47.64509)', 'PUGET SOUND ENERGY INC', '53035091301', '848', '6', '39')
# ('1GYKPSRL9R', 'Jefferson', 'Port Ludlow', 'WA', '98365', 2024, 'CADILLAC', 'LYRIQ', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '24', 270702491, 'POINT (-122.68475 47.92989)', 'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY', '53031950301', '3008', '6', '30')
# ('KM8KN4DEXR', 'Thurston', 'Olympia', 'WA', '98501', 2024, 'HYUNDAI', 'IONIQ 5', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '35', 269272153, 'POINT (-122.89166 47.03956)', 'PUGET SOUND ENERGY INC', '53067011821', '2742', '10', '28')
# ('KNDRMDLH9N', 'Clark', 'Vancouver', 'WA', '98664', 2022, 'KIA', 'SORENTO', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 32, 0, '49', 182334575, 'POINT (-122.59219 45.62158)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011041208', '2977', '3', '8')
# ('KL8CL6S0XE', 'King', 'Shoreline', 'WA', '98133', 2014, 'CHEVROLET', 'SPARK', 'Battery Electric Vehicle (BEV)', 'Clean Alternative Fuel Vehicle Eligible', 82, 0, '32', 224451370, 'POINT (-122.35029 47.71871)', 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)', '53033020700', '3009', '7', '21')
# ('1FT6W5L74R', 'King', 'North Bend', 'WA', '98045', 2024, 'FORD', 'F-150', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '5', 273898985, 'POINT (-121.7831 47.49348)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033032704', '3009', '8', '6')
# ('7SAXCBE64P', 'King', 'Bellevue', 'WA', '98006', 2023, 'TESLA', 'MODEL X', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '41', 260886783, 'POINT (-122.12096 47.55584)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033024904', '3009', '9', '42')
# ('JTMAB3FV5P', 'Clark', 'Vancouver', 'WA', '98685', 2023, 'TOYOTA', 'RAV4 PRIME', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Clean Alternative Fuel Vehicle Eligible', 42, 0, '49', 236315537, 'POINT (-122.70303 45.70954)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011040904', '2977', '3', '25')
# ('5YJSA1E23M', 'King', 'Bellevue', 'WA', '98004', 2021, 'TESLA', 'MODEL S', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '48', 132148894, 'POINT (-122.1872 47.61001)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033024002', '3009', '9', '42')
# ('1N4CZ1CV2P', 'Jefferson', 'Port Townsend', 'WA', '98368', 2023, 'NISSAN', 'LEAF', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '24', 259761029, 'POINT (-122.77263 48.1212)', 'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY', '53031950602', '3008', '6', '30')
# ('LYVBR0DM5K', 'Clark', 'Vancouver', 'WA', '98683', 2019, 'VOLVO', 'XC60', 'Plug-in Hybrid Electric Vehicle (PHEV)', 'Not eligible due to low battery range', 17, 52900, '17', 259388391, 'POINT (-122.49212 45.60365)', 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)', '53011041310', '2977', '3', '25')
# ('5YJ3E1EC2M', 'King', 'Federal Way', 'WA', '98023', 2021, 'TESLA', 'MODEL 3', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '30', 179445367, 'POINT (-122.36321 47.3084)', 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)', '53033030201', '3009', '9', '14')
# ('WVGDMPE25M', 'Snohomish', 'Everett', 'WA', '98204', 2021, 'VOLKSWAGEN', 'ID.4', 'Battery Electric Vehicle (BEV)', 'Eligibility unknown as battery range has not been researched', 0, 0, '21', 154455829, 'POINT (-122.27557 47.88936)', 'PUGET SOUND ENERGY INC', '53061041901', '3213', '2', '7')

# %%
# Fetching count of records
cur.execute("SELECT COUNT(*) FROM ElectricVehicles")
record_count = cur.fetchone()[0]

print(f"Total number of records: {record_count}")

conn.close()  # Closing database connection
# Out:
# Total number of records: 4155
